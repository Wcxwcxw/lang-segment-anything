# %%
import matplotlib.pyplot as plt
from PIL import Image
image = "/data/chenxu/dataset/person_stop/stop_small/images_train/20000328.jpg"
img = Image.open(image).convert("RGB")
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 1279.5, 719.5, -0.5)

# %% [markdown]
# ## result
# 1. text_prompt = "person on train tracks"
# No objects of the 'person on train tracks' prompt detected in the image.
#
# 2. text_prompt = "animal on train tracks"
# No objects of the 'person on train tracks' prompt detected in the image.

# %%
image = "/data/chenxu/dataset/person_stop/person_small/images_train/object_000013.jpg"
img = Image.open(image).convert("RGB")
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 1279.5, 719.5, -0.5)

# %% [markdown]
# ## results
# 1. text_prompt = "animal on train tracks"

# %%
image = "object_000013.png"
img = Image.open(image).convert("RGB")
plt.imshow(img)
plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1466936/120876919.py in <module>
#       1 image = "object_000013.png"
# ----> 2 img = Image.open(image).convert("RGB")
#       3 plt.imshow(img)
#       4 plt.axis("off")
#
# NameError: name 'Image' is not defined
